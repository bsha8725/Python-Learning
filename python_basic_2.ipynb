# %%
#列表:以中括号形式数据集合,容器类型
#列表:他可以存储不同数据类型的容器
my_list = [1,1.33,'abc,',True]
print(my_list,type(my_list))
#下标,索引(下标是可以有负数)
result = my_list[2]
result

# %%
#列表增删改查

#查询数据:
# my_list = [1,1.33,'abc,',True]
# result = my_list[-2]
# result 
# #增加数据
# my_list = []
# my_list.append('王振京')
# my_list.append('张利鹏')

# my_list
# #在指定位置增加数据
# #增加一条数据,并设置这条数据的索引
# my_list.insert(1,'李老师')
# my_list

#在列表里面追加一个列表
# my_list = ['王振京','李老师']
# my_list1 = ['西瓜','芒果','草莓']
#给my_list追加了一个自己,垃圾命名规则
# my_list.append(my_list)
# print(my_list)
#二维列表(数组)
# [['王振京','李老师',['西瓜','芒果','草莓']]]
#西瓜' 1 ['西瓜','芒果','草莓']2
#取出西瓜
# print(my_list[2])  
# result = my_list[2]
# value = result[0]
# print(value)
# my_list[2][0] 
#根据指定数据删除
# my_list = ['王振京','李老师','赵老师','王老师']
# my_list.remove('王振京')
# my_list
# #根据下标
# del my_list[0]
# my_list
# my_list = ['王振京','李老师','赵老师','王老师']
# del my_list 
# my_list
# a = 10 
# del a 
#删除最后一条数据
#pop根据下标删除数据
#pop默认删除最后一条,可以根据索引指定删除
# my_list = ['王振京','李老师','赵老师','王老师']
# result = my_list.pop(1)
# print(my_list,result)
#判断数据是否在列表当中
# my_list = ['王振京','李老师','赵老师','王老师']
# # result ="赵老师" in my_list
# # result
# #统计一下列表元素的个数
# result = len(my_list)
# result 
my_list = [8,2,3,4,5]
# result = my_list.index(2)
# result
# result = my_list.count(5)
# result
# #把原有的列表直接排序,没有返回结果
my_list.sort()
print(my_list)
# print(my_list)
# 要求:对着敲一遍,自己敲一遍 默写一遍

# %%
#字符串 #有序的数据集合
#使用'' "" """ """
my_str = "hello"
#根据数据取下标#没有此字符串 崩溃
result = my_str.index('h')
# result 
#find查询 如果没有找到会返回-1
# result = my_str.find('i')
# result
#len统计长度
# result = len(my_str)
# result

# result = my_str.count('l')
# result
#替换 hexxo 
# result =my_str.replace('l','x')
# result
my_str = "苹果.句子.鸭梨"
result = my_str.split('.')
# result
#---------------------------------------------
#判断是否以指定数据开头 爬虫
# my_url = "http:www.baidu.com"
# result = my_url.startswith('http')
# my_url = "http:www.baidu.com"
# result = my_url.endswith('com')
# result
#结尾
#需求将下列字符串进行分割 
my_str = "aaabbcc"
result = my_str.partition('bb')
# type(result)
print(type(result))

# #去除空格
my_str = "hello"
# print(my_str)
result = my_str.strip(')
# # # print(result)
# result = my_str.lstrip()
# # print(result)
result = my_str.lstrip('a')

# result

# %%
# my_str = "苹果,橘子,鸭梨"

# # result = my_str[2]
# # result 

# result = my_str.split(',')
# type(result)

# %%
#切片:根据下标的范围,获取一部分数据,列表,字符串
#range(起始数据,结束数据,步长)
#起始数据
# my_str = 'hello'
#正常写法1 
# my_str[0:4:1]
# #省略写法一(省略步长,步长默认是1 )
# my_str[0:4]
# #省略式写法二(省略起始数据)
# my_str[:4]
#负数下标去切(从后往前查,从前往后切)
# my_str[-3:]
#需求,所有的字符串
# my_str[::]
#从后向前切(步长为负数,从后向前切)
# my_str[::-1]
#使用正数下标获取数据,步长为负数(结束数据默认不截取)
# my_str[3:0:-1]
#作业1:
my_str = 'abcdefg'

# my_str = [-3:0:1]#为什么
# my_str = [-3:0:-1]# 详细的切片步骤,用文字表名,如果运行不出来为什么

# %%
#元组:以小括号形式存在的数据集合(1,1.34,True)
#注意点:元组可以查询数据,但是不可以改变和删除
# my_tuple = (1,1.34,True,'abc')
#根据下标获取数据
# my_tuple[-2]
# del my_tuple
#修改也不可以
# my_tuple[0] = '2'
#元组不可以修改数据 列表可以修改数据 里面的列表1.5这个元素,改变成2

my_tuple = (1,[1,1.5])

my_list = my_tuple[1]
#没有改变元组里面列表的元素
#这行代码代表的意思是:相当于创建了一个新的列表,只不过名字和my_list一模一样
my_list = [1,2]
print(my_tuple) 
#作业2:使用方法,修改元组里面列表里面的元素---2

# %%
#元组的方法
#创建一个新的元组
#坑:元组只有一条数据时,数据时什么类型,元组就是什么类型
my_tuple = (1,)
my_tuple[0]
print(my_tuple,type(my_tuple))
#判断数据是否在元组当中
my_tuple = ('哈哈',2,3,3,3,3,3)
# result  =5 in my_tuple
# result 

result = my_tuple.index('哈哈')
result 
len(my_tuple)
my_tuple.count(3)

# %%
#集合 set:以大括号形式的数据容器,特性:集合不允许有重复的数据 [1,2,2,2,2,2,2,3,4,5]
#特性2:集合是无序的 
my_set = {3,3,True,'123'}
# print(my_set,type(my_set))
#坑: 创建空的集合  {}数据类型字典,也是以大括号形式存在的
# my_set = set()
# print(my_set,type(my_set))
#测试无序
# result = my_set[0]
# result 

# len(my_set) 
#删除
# my_set.remove(3)
# my_set 
#重点 相互转换 list - tuple  list --> set 

# #set 给列表去重
# my_list = [1,2,3,3,3,3,3]
# print(my_list)
# #list---->set 
# my_set = set(my_list)
# my_set 
# #set --- >list 
# my_list = list(my_set)
# my_list 

# #tuple --list 
# my_tuple = (1,1.34,True,'abc') 
# my_list =list(my_tuple)
# print(my_list,type(my_list))
#总结:列表,集合,元组,相互转换 转换列表list() 转换元组 tuple() 转换集合 set()
# Out:
# [1, 2, 3, 3, 3, 3, 3]
# [1, 1.34, True, 'abc'] <class 'list'>

# %%
#字典:以大括号形式的键值对组合数据容器{name:'人间不值',age:18}
#key value key永远是唯一 (99%key字符串类型)
my_dict = {'name':'人间不值','age':18}
#一个元素,一个键值对,代表一条数据,
#字典特性:字典是无序的

# print(len(my_dict),type(my_dict),my_dict)

#取出数据,查询数据 利用key来取value
value = my_dict["age"]
#没有key 硬取 
# value = my_dict['sex']
# value 
#get方式取值
value = my_dict.get('sex')
print(value)
# Out:
# None

# %%
#定义一个空的字典
my_dict = {} 
#增加数据
my_dict['age'] = 18 
my_dict['sex'] = '女'
my_dict['name'] = '人间不值'
my_dict['address'] = '北京'

print(my_dict)
#验证key的唯一性
#更新键值对,改变名字
my_dict['name'] = '值得'
#修改键值对
print(my_dict)
#删除数据(随机删除)
#返回值随机删除的数据
value = my_dict.popitem()
print(my_dict)
print(value)
#指定删除
value =my_dict.pop('sex')
print(my_dict)
print(value) 

#学会不代表你会了
# Out:
# {'age': 18, 'sex': '女', 'name': '人间不值', 'address': '北京'}
# {'age': 18, 'sex': '女', 'name': '人间不值'}
# ('address', '北京')
